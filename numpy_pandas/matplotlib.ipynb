# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import figure

x=np.linspace(start=0,stop=10,num=100)
y1=np.sin(x)
y2=np.cos(x)
plt.figure(figsize=(10,6))
plt.subplot(2,1,1)

plt.xlim(0,10)
plt.ylim(-1,1)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title('sin')
plt.plot(x,y1)

plt.subplot(2,1,2)

plt.xlim(0,10)
plt.ylim(-1,1)
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.title('cos')
plt.plot(x,y2)
plt.show()

# %%
import pandas as pd
from matplotlib import rcParams
rcParams["font.sans-serif"]=["SimHei"]
df=pd.read_csv("C:\\Users\\x8983\\PycharmProjects\\Rag\\numpy_pandas\\data\\weather.csv")
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.hist(df["precipitation"],bins=5)
ax1.set_xlabel("降水量")
ax1.set_ylabel("出现频次")
# Out:
# Text(0, 0.5, '出现频次')

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["font.sans-serif"]=["SimHei"]
rcParams["axes.unicode_minus"]=False
df=pd.read_csv('data/weather.csv')
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.scatter(df["temp_max"],df["precipitation"])
ax1.set_xlabel("最高气温")
ax1.set_ylabel("降水量")
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["font.sans-serif"]=["SimHei"]
rcParams["axes.unicode_minus"]=False
df=pd.read_csv('data/weather.csv')
df["date"]=pd.to_datetime(df['date'])
def year_color(x):
    match x.year:
        case 2012:
            return "r"
        case 2013:
            return "g"
        case 2014:
            return "b"
        case 2015:
            return "k"
df["color"]=pd["date"].apply(year_color)
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.scatter(df["temp_max"],df["precipitation"],c=df["color"],alpha=0.5)
ax1.set_xlabel("最高气温")
ax1.set_ylabel("降水量")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      14         case 2014:
#      15             return "b"
#      16         case 2015:
#      17             return "k"
# ---> 18 df["color"]=pd["date"].apply(year_color)
#      19 fig=plt.figure()
#      20 ax1=fig.add_subplot(1,1,1)
#      21 ax1.scatter(df["temp_max"],df["precipitation"],c=df["color"],alpha=0.5)
#
# TypeError: 'module' object is not subscriptable
